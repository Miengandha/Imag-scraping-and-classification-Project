# %% [markdown]
# # Image Scraping Classification
# #### (web scraping script)

# %%
import pandas as pd
import numpy as np
from selenium import webdriver
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By
import time
import requests
import os

import warnings
warnings.filterwarnings('ignore')

# %%
driver= webdriver.Chrome(r'C:\Users\user\Downloads\chromedriver_win32 (3)\chromedriver.exe')
time.sleep(2)

# %%
url='https://www.amazon.in/'
driver.get(url)

# %%
search_prod=driver.find_element("xpath","/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[2]/div[1]/input")
search_prod.send_keys("sarees")
search_bar=driver.find_element("xpath","/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[3]/div/span/input").click()

# %%
for _ in range(20):
    driver.execute_script("window.scrollBy(0,1000)")
    
saree_img = driver.find_elements(By.XPATH,'//img[@class="s-image"]')

img_urls = []
img_data = []
for image in saree_img:
    source= image.get_attribute('src')
    if source is not None:
        if(source[0:4] == 'http'):
            img_urls.append(source)
            
                
for i in range(len(img_urls)):
    if i > 70:
        break
    print("Downloading {0} of {1} images" .format(i, 70))
    response= requests.get(img_urls[i])
    file = open(r"C:\Users\user\Desktop\IMAGES\SAREES\saree"+str(i)+".jpg", "wb")
    file.write(response.content)

# %%
search_prod=driver.find_element("xpath","/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[2]/div[1]/input")
search_prod.send_keys("trousers men")
search_bar=driver.find_element("xpath","/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[3]/div/span/input").click()

# %%
for _ in range(20):
    driver.execute_script("window.scrollBy(0,1000)")
    
trousers_img = driver.find_elements(By.XPATH,'//img[@class="s-image"]')

trou_img_urls = []
trou_img_data = []
for trousers_image in trousers_img:
    source_img= trousers_image.get_attribute('src')
    if source_img is not None:
        if(source_img[0:4] == 'http'):
            trou_img_urls.append(source_img)
            
                
for i in range(len(trou_img_urls)):
    if i > 70:
        break
    print("Downloading {0} of {1} images" .format(i, 70))
    response= requests.get(trou_img_urls[i])
    file = open(r"C:\Users\user\Desktop\IMAGES\TROUSERS(men)\trousers"+str(i)+".jpg", "wb")
    file.write(response.content)

# %%
search_prod=driver.find_element("xpath","/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[2]/div[1]/input")
search_prod.send_keys("jeans men")
search_bar=driver.find_element("xpath","/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[3]/div/span/input").click()

# %%
for _ in range(20):
    driver.execute_script("window.scrollBy(0,1000)")
    
jeans_img = driver.find_elements(By.XPATH,'//img[@class="s-image"]')

jeans_img_urls = []
jeans_img_data = []
for jeans_image in jeans_img:
    source_images= jeans_image.get_attribute('src')
    if source_images is not None:
        if(source_images[0:4] == 'http'):
            jeans_img_urls.append(source_images)
            
                
for i in range(len(jeans_img_urls)):
    if i > 70:
        break
    print("Downloading {0} of {1} images" .format(i, 70))
    response= requests.get(jeans_img_urls[i])
    file = open(r"C:\Users\user\Desktop\IMAGES\JEANS(men)\jeans"+str(i)+".jpg", "wb")
    file.write(response.content)

# %%
driver.close()
